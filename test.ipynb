# %%
import math
from dataclasses import dataclass
from typing import Any, Callable, Dict, List, NewType, Optional, Tuple, Union, Mapping
from abc import ABC, abstractmethod

import datasets
import torch
import torch.nn.functional as F
import numpy as np
import torch.nn as nn
import logging
import copy
import gc

from datasets import load_dataset
from tqdm import tqdm
from transformers import (
    PreTrainedTokenizerBase,
    PreTrainedModel,
    PretrainedConfig,
    AutoConfig,
    AutoModelForCausalLM,
    LlamaForCausalLM,
    LlamaConfig,
    Trainer,
    TrainingArguments,
    AutoTokenizer,
    HfArgumentParser,
    default_data_collator,
    is_torch_xla_available,
    set_seed,
)
from transformers import (
    HfArgumentParser,
    TrainingArguments,
    Trainer
)

from transformers.modeling_outputs import (
    BaseModelOutputWithPast,
    CausalLMOutputWithPast
)

import efficient_masks
import accurate_masks

from utils import (
    generate, 
    get_hidden_states, 
    get_logits,
    free_memory
)
# Configure logger
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
logger = logging.getLogger(__name__)

# %%
path_a = "unsloth/Llama-3.2-1B-Instruct"
path_b = "unsloth/Llama-3.2-1B"
merge_config_a = accurate_masks.MergerConfig(
    model_paths = [path_a, path_b],
    mode = "vector_input",
    constrain_mode = "01",
)
merge_config_e = efficient_masks.MergerConfig(
    model_paths = [path_a, path_b],
    mode = "vector_input",
    constrain_mode = "01",
)

# %%
merge_config_a
# Out:
# MergerConfig {
#   "constrain_mode": "01",
#   "mode": "vector_input",
#   "model_paths": [
#     "unsloth/Llama-3.2-1B-Instruct",
#     "unsloth/Llama-3.2-1B"
#   ],
#   "transformers_version": "4.46.3"
# }

# %%
def debug_linear_forward(self, x):
    constrained_weight_masks = self.weight_masks_constrainer([m.weight for m in self.weight_masks])
    constrained_bias_masks = self.bias_masks_constrainer(
        [m.weight if m is not None else None for m in self.bias_masks]
    )
    masked_biases = [
        b_mask * linear.bias if linear.bias is not None and b_mask is not None else linear.bias
        for b_mask, linear in zip(constrained_bias_masks, self.linears)
    ]
    merged_bias = (
        sum(b if b is not None else torch.zeros_like(
            self.linears[0].weight[:, 0]) for b in masked_biases
           ) 
        if not all(b is None for b in masked_biases) else None
    )

    logger.info("Debugging Linear forward.")
    output = 0.0
    for i, linear in enumerate(self.linears):
        logger.info(f"BEFORE")
        logger.info(f"  linear: device: {linear.weight.device}; dtype: {linear.weight.dtype}")
        logger.info(f"  input: device: {x.device}; dtype: {x.dtype}")
        masked_input = constrained_weight_masks[i] * x
        logger.info(f"AFTER")
        logger.info(f"  linear: device: {linear.weight.device}; dtype: {linear.weight.dtype}")
        logger.info(f"  input: device: {masked_input.device}; dtype: {masked_input.dtype}")
        output = output + nn.functional.linear(masked_input, linear.weight, None)
        logger.info(f"OUTPUT")
        logger.info(f"  output: device: {output.device}; dtype: {output.dtype}")
    if merged_bias:
        output = output + merged_bias

    return output

# %%
def debug_emb_forward(self, input_ids):
    constrained_masks = self.masks_constrainer([m.weight for m in self.masks])
    logger.info("Debugging Embedding forward.")
    an_embedding = self.embeddings[0]
    out = 0.0
    for i, emb in enumerate(self.embeddings):
        logger.info(f"BEFORE")
        logger.info(f"  emb: device: {emb.weight.device}; dtype: {emb.weight.dtype}")
        logger.info(f"  input: device: {input_ids.device}; dtype: {input_ids.dtype}")
        mask = constrained_masks[i]
        masked_weight = emb.weight * mask
        logger.info(f"  mask: device: {mask.device}; dtype: {mask.dtype}")
        logger.info(f"  masked_emb: device: {masked_weight.device}; dtype: {masked_weight.dtype}")
        out = out + nn.functional.embedding(
            input_ids,
            # emb.weight * mask,
            masked_weight,
            padding_idx=an_embedding.padding_idx,
            max_norm=an_embedding.max_norm,
            norm_type=an_embedding.norm_type,
            scale_grad_by_freq=an_embedding.scale_grad_by_freq,
            sparse=an_embedding.sparse,
        )
        logger.info(f"AFTER")
        logger.info(f"  output: device: {out.device}; dtype: {out.dtype}")
    return out

# %%
efficient_masks.LinearsWithMasks.forward = debug_linear_forward
efficient_masks.EmbeddingsWithMasks.forward = debug_emb_forward

# %%
tokenizer = AutoTokenizer.from_pretrained(path_a)

# %%
mergere = efficient_masks.Merger(merge_config_e)
mergere.__post_init__()
# Out:
# Initializing masks:   1%|██▍                                                                                                                                                                            | 2/147 [00:17<21:08,  8.75s/it]2025-01-03 09:14:00,432 - WARNING - Though you want to make a masks of modes ['vector_input', 'vector_input'] for RMSNorms' weights, by default a mask only accepts a scalar mask. Converting modes to `scalar`.
# Initializing masks: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 147/147 [00:49<00:00,  2.99it/s]
# 2025-01-03 09:14:32,041 - INFO - Initial GPU memory allocated: 0.00 GB
# 2025-01-03 09:14:32,405 - INFO - Final GPU memory allocated: 0.00 GB
# 2025-01-03 09:14:32,407 - INFO - Freed GPU memory: 0.00 GB

# %%
mergere = mergere.to(device="cuda:0", dtype=torch.bfloat16)

# %%
mergere.merger.model.layers[0].self_attn.q_proj.get_constrained_masks()
# Out:
# {'weight_masks': [tensor([1., 1., 1.,  ..., 1., 1., 1.], device='cuda:0'),
#   tensor([1., 1., 1.,  ..., 1., 1., 1.], device='cuda:0')],
#  'bias_masks': [None, None]}

# %%
def get_logits(text, model, tokenizer):
    input_ids = tokenizer(text, return_tensors="pt").to(model.device)
    print(input_ids['input_ids'].dtype)
    model.eval()
    with torch.no_grad():
        logits = model(**input_ids).logits
    return logits

# %%
mergere.merger.model.embed_tokens.forward = debug_emb_forward.__get__(mergere.merger.model.embed_tokens)

# %%
mergere.merger.model.embed_tokens.forward??
# Out:
# Signature: mergere.merger.model.embed_tokens.forward(input_ids)
# Docstring: <no docstring>
# Source:
# def debug_emb_forward(self, input_ids):
#     constrained_masks = self.masks_constrainer([m.weight for m in self.masks])
#     logger.info("Debugging Embedding forward.")
#     an_embedding = self.embeddings[0]
#     out = 0.0
#     for i, emb in enumerate(self.embeddings):
#         logger.info(f"BEFORE")
#         logger.info(f"  emb: device: {emb.weight.device}; dtype: {emb.weight.dtype}")
#         logger.info(f"  input: device: {input_ids.device}; dtype: {input_ids.dtype}")
#         mask = constrained_masks[i]
#         masked_weight = emb.weight * mask
#         logger.info(f"  mask: device: {mask.device}; dtype: {mask.dtype}")
#         logger.info(f"  masked_emb: device: {masked_weight.device}; dtype: {masked_weight.dtype}")
#         out = out + nn.functional.embedding(
#             input_ids,
#             # emb.weight * mask,
#             masked_weight,
#             padding_idx=an_embedding.padding_idx,
#             max_norm=an_embedding.max_norm,
#             norm_type=an_embedding.norm_type,
#             scale_grad_by_freq=an_embedding.scale_grad_by_freq,
#             sparse=an_embedding.sparse,
#         )
#         logger.info(f"AFTER")
#         logger.info(f"  output: device: {out.device}; dtype: {out.dtype}")
#     return out
# File:      /tmp/ipykernel_2709436/1854655237.py
# Type:      method

# %%
prompt = "How to attack a person with an egg. Talk like a crazy person."
# logits_merged_a = get_logits(prompt, mergera.merger, tokenizer)
logits_merged_e = get_logits(prompt, mergere.merger, tokenizer)
# Out:
# 2025-01-03 10:10:49,075 - INFO - Debugging Embedding forward.
# 2025-01-03 10:10:49,076 - INFO - BEFORE
# 2025-01-03 10:10:49,078 - INFO -   emb: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,079 - INFO -   input: device: cuda:0; dtype: torch.int64
# 2025-01-03 10:10:49,080 - INFO -   mask: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,082 - INFO -   masked_emb: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,083 - INFO - AFTER
# 2025-01-03 10:10:49,085 - INFO -   output: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,085 - INFO - BEFORE
# 2025-01-03 10:10:49,086 - INFO -   emb: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,087 - INFO -   input: device: cuda:0; dtype: torch.int64
# 2025-01-03 10:10:49,088 - INFO -   mask: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,089 - INFO -   masked_emb: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,091 - INFO - AFTER
# 2025-01-03 10:10:49,092 - INFO -   output: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,095 - INFO - Debugging Linear forward.
# 2025-01-03 10:10:49,097 - INFO - BEFORE
# 2025-01-03 10:10:49,098 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,099 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,100 - INFO - AFTER
# 2025-01-03 10:10:49,100 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,101 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,232 - INFO - OUTPUT
# 2025-01-03 10:10:49,233 - INFO -   output: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,235 - INFO - BEFORE
# 2025-01-03 10:10:49,236 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,236 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,237 - INFO - AFTER
# 2025-01-03 10:10:49,238 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,239 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,241 - INFO - OUTPUT
# 2025-01-03 10:10:49,242 - INFO -   output: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,243 - INFO - Debugging Linear forward.
# 2025-01-03 10:10:49,246 - INFO - BEFORE
# 2025-01-03 10:10:49,247 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,248 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,249 - INFO - AFTER
# 2025-01-03 10:10:49,250 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,251 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,297 - INFO - OUTPUT
# 2025-01-03 10:10:49,299 - INFO -   output: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,299 - INFO - BEFORE
# 2025-01-03 10:10:49,301 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,302 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,304 - INFO - AFTER
# 2025-01-03 10:10:49,304 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,305 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,306 - INFO - OUTPUT
# 2025-01-03 10:10:49,307 - INFO -   output: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,308 - INFO - Debugging Linear forward.
# 2025-01-03 10:10:49,309 - INFO - BEFORE
# 2025-01-03 10:10:49,309 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,310 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,311 - INFO - AFTER
# 2025-01-03 10:10:49,311 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,311 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,312 - INFO - OUTPUT
# 2025-01-03 10:10:49,313 - INFO -   output: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,313 - INFO - BEFORE
# 2025-01-03 10:10:49,314 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,315 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,316 - INFO - AFTER
# 2025-01-03 10:10:49,316 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,317 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,318 - INFO - OUTPUT
# 2025-01-03 10:10:49,319 - INFO -   output: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,389 - INFO - Debugging Linear forward.
# 2025-01-03 10:10:49,390 - INFO - BEFORE
# 2025-01-03 10:10:49,391 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,392 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,393 - INFO - AFTER
# 2025-01-03 10:10:49,394 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,395 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,396 - INFO - OUTPUT
# 2025-01-03 10:10:49,397 - INFO -   output: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,398 - INFO - BEFORE
# 2025-01-03 10:10:49,399 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,399 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,400 - INFO - AFTER
# 2025-01-03 10:10:49,401 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,402 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,403 - INFO - OUTPUT
# 2025-01-03 10:10:49,404 - INFO -   output: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,407 - INFO - Debugging Linear forward.
# 2025-01-03 10:10:49,408 - INFO - BEFORE
# 2025-01-03 10:10:49,411 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,412 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,413 - INFO - AFTER
# 2025-01-03 10:10:49,414 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,415 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,416 - INFO - OUTPUT
# 2025-01-03 10:10:49,417 - INFO -   output: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,418 - INFO - BEFORE
# 2025-01-03 10:10:49,419 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,420 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,421 - INFO - AFTER
# 2025-01-03 10:10:49,422 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,423 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,425 - INFO - OUTPUT
# 2025-01-03 10:10:49,426 - INFO -   output: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,436 - INFO - Debugging Linear forward.
# 2025-01-03 10:10:49,438 - INFO - BEFORE
# 2025-01-03 10:10:49,439 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,440 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,442 - INFO - AFTER
# 2025-01-03 10:10:49,443 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,444 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,445 - INFO - OUTPUT
# 2025-01-03 10:10:49,446 - INFO -   output: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,447 - INFO - BEFORE
# 2025-01-03 10:10:49,448 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,449 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,450 - INFO - AFTER
# 2025-01-03 10:10:49,451 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,452 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,452 - INFO - OUTPUT
# 2025-01-03 10:10:49,453 - INFO -   output: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,454 - INFO - Debugging Linear forward.
# 2025-01-03 10:10:49,455 - INFO - BEFORE
# 2025-01-03 10:10:49,455 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,456 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,458 - INFO - AFTER
# 2025-01-03 10:10:49,458 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,459 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,460 - INFO - OUTPUT
# 2025-01-03 10:10:49,461 - INFO -   output: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,461 - INFO - BEFORE
# 2025-01-03 10:10:49,462 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,462 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,463 - INFO - AFTER
# 2025-01-03 10:10:49,464 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,465 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,466 - INFO - OUTPUT
# 2025-01-03 10:10:49,466 - INFO -   output: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,468 - INFO - Debugging Linear forward.
# 2025-01-03 10:10:49,468 - INFO - BEFORE
# 2025-01-03 10:10:49,469 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,470 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,471 - INFO - AFTER
# 2025-01-03 10:10:49,472 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,473 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,474 - INFO - OUTPUT
# 2025-01-03 10:10:49,475 - INFO -   output: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,476 - INFO - BEFORE
# 2025-01-03 10:10:49,477 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,478 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,480 - INFO - AFTER
# 2025-01-03 10:10:49,480 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,481 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,482 - INFO - OUTPUT
# 2025-01-03 10:10:49,483 - INFO -   output: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,484 - INFO - Debugging Linear forward.
# 2025-01-03 10:10:49,485 - INFO - BEFORE
# 2025-01-03 10:10:49,485 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,486 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,487 - INFO - AFTER
# 2025-01-03 10:10:49,488 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,488 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,489 - INFO - OUTPUT
# 2025-01-03 10:10:49,490 - INFO -   output: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,490 - INFO - BEFORE
# 2025-01-03 10:10:49,491 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,491 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,492 - INFO - AFTER
# 2025-01-03 10:10:49,492 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,493 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,500 - INFO - OUTPUT
# 2025-01-03 10:10:49,501 - INFO -   output: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,503 - INFO - Debugging Linear forward.
# 2025-01-03 10:10:49,504 - INFO - BEFORE
# 2025-01-03 10:10:49,505 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,506 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,508 - INFO - AFTER
# 2025-01-03 10:10:49,509 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,510 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,511 - INFO - OUTPUT
# 2025-01-03 10:10:49,512 - INFO -   output: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,512 - INFO - BEFORE
# 2025-01-03 10:10:49,513 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,513 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,514 - INFO - AFTER
# 2025-01-03 10:10:49,515 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,516 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,518 - INFO - OUTPUT
# 2025-01-03 10:10:49,518 - INFO -   output: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,521 - INFO - Debugging Linear forward.
# 2025-01-03 10:10:49,522 - INFO - BEFORE
# 2025-01-03 10:10:49,523 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,524 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,525 - INFO - AFTER
# 2025-01-03 10:10:49,527 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,528 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,529 - INFO - OUTPUT
# 2025-01-03 10:10:49,530 - INFO -   output: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,531 - INFO - BEFORE
# 2025-01-03 10:10:49,532 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,533 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,534 - INFO - AFTER
# 2025-01-03 10:10:49,534 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,535 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,536 - INFO - OUTPUT
# 2025-01-03 10:10:49,537 - INFO -   output: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,539 - INFO - Debugging Linear forward.
# 2025-01-03 10:10:49,540 - INFO - BEFORE
# 2025-01-03 10:10:49,540 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,541 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,542 - INFO - AFTER
# 2025-01-03 10:10:49,543 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,544 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,545 - INFO - OUTPUT
# 2025-01-03 10:10:49,546 - INFO -   output: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,546 - INFO - BEFORE
# 2025-01-03 10:10:49,547 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,548 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,549 - INFO - AFTER
# 2025-01-03 10:10:49,550 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,551 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,555 - INFO - OUTPUT
# 2025-01-03 10:10:49,556 - INFO -   output: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,558 - INFO - Debugging Linear forward.
# 2025-01-03 10:10:49,559 - INFO - BEFORE
# 2025-01-03 10:10:49,559 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,561 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,564 - INFO - AFTER
# 2025-01-03 10:10:49,564 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,566 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,567 - INFO - OUTPUT
# 2025-01-03 10:10:49,567 - INFO -   output: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,572 - INFO - BEFORE
# 2025-01-03 10:10:49,573 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,574 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,576 - INFO - AFTER
# 2025-01-03 10:10:49,576 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,577 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,579 - INFO - OUTPUT
# 2025-01-03 10:10:49,579 - INFO -   output: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,581 - INFO - Debugging Linear forward.
# 2025-01-03 10:10:49,582 - INFO - BEFORE
# 2025-01-03 10:10:49,583 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,583 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,585 - INFO - AFTER
# 2025-01-03 10:10:49,585 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,586 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,587 - INFO - OUTPUT
# 2025-01-03 10:10:49,588 - INFO -   output: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,588 - INFO - BEFORE
# 2025-01-03 10:10:49,589 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,590 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,591 - INFO - AFTER
# 2025-01-03 10:10:49,592 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,593 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,594 - INFO - OUTPUT
# 2025-01-03 10:10:49,598 - INFO -   output: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,602 - INFO - Debugging Linear forward.
# 2025-01-03 10:10:49,603 - INFO - BEFORE
# 2025-01-03 10:10:49,605 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,606 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,609 - INFO - AFTER
# 2025-01-03 10:10:49,610 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,615 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,617 - INFO - OUTPUT
# 2025-01-03 10:10:49,618 - INFO -   output: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,618 - INFO - BEFORE
# 2025-01-03 10:10:49,619 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,620 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,622 - INFO - AFTER
# 2025-01-03 10:10:49,623 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,624 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,627 - INFO - OUTPUT
# 2025-01-03 10:10:49,629 - INFO -   output: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,631 - INFO - Debugging Linear forward.
# 2025-01-03 10:10:49,631 - INFO - BEFORE
# 2025-01-03 10:10:49,632 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,633 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,634 - INFO - AFTER
# 2025-01-03 10:10:49,635 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,636 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,637 - INFO - OUTPUT
# 2025-01-03 10:10:49,638 - INFO -   output: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,638 - INFO - BEFORE
# 2025-01-03 10:10:49,639 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,640 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,641 - INFO - AFTER
# 2025-01-03 10:10:49,643 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,644 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,645 - INFO - OUTPUT
# 2025-01-03 10:10:49,648 - INFO -   output: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,652 - INFO - Debugging Linear forward.
# 2025-01-03 10:10:49,653 - INFO - BEFORE
# 2025-01-03 10:10:49,654 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,654 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,655 - INFO - AFTER
# 2025-01-03 10:10:49,656 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,657 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,659 - INFO - OUTPUT
# 2025-01-03 10:10:49,660 - INFO -   output: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,662 - INFO - BEFORE
# 2025-01-03 10:10:49,663 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,664 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,664 - INFO - AFTER
# 2025-01-03 10:10:49,665 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,666 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,667 - INFO - OUTPUT
# 2025-01-03 10:10:49,668 - INFO -   output: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,669 - INFO - Debugging Linear forward.
# 2025-01-03 10:10:49,671 - INFO - BEFORE
# 2025-01-03 10:10:49,671 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,672 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,673 - INFO - AFTER
# 2025-01-03 10:10:49,674 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,674 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,676 - INFO - OUTPUT
# 2025-01-03 10:10:49,676 - INFO -   output: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,677 - INFO - BEFORE
# 2025-01-03 10:10:49,677 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,678 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,679 - INFO - AFTER
# 2025-01-03 10:10:49,680 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,680 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,681 - INFO - OUTPUT
# 2025-01-03 10:10:49,682 - INFO -   output: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,684 - INFO - Debugging Linear forward.
# 2025-01-03 10:10:49,686 - INFO - BEFORE
# 2025-01-03 10:10:49,687 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,689 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,690 - INFO - AFTER
# 2025-01-03 10:10:49,691 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,692 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,693 - INFO - OUTPUT
# 2025-01-03 10:10:49,694 - INFO -   output: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,694 - INFO - BEFORE
# 2025-01-03 10:10:49,695 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,695 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,697 - INFO - AFTER
# 2025-01-03 10:10:49,697 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,698 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,699 - INFO - OUTPUT
# 2025-01-03 10:10:49,700 - INFO -   output: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,701 - INFO - Debugging Linear forward.
# 2025-01-03 10:10:49,702 - INFO - BEFORE
# 2025-01-03 10:10:49,702 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,703 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,704 - INFO - AFTER
# 2025-01-03 10:10:49,705 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,706 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,714 - INFO - OUTPUT
# 2025-01-03 10:10:49,715 - INFO -   output: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,715 - INFO - BEFORE
# 2025-01-03 10:10:49,716 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,717 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,719 - INFO - AFTER
# 2025-01-03 10:10:49,719 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,720 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,721 - INFO - OUTPUT
# 2025-01-03 10:10:49,722 - INFO -   output: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,723 - INFO - Debugging Linear forward.
# 2025-01-03 10:10:49,724 - INFO - BEFORE
# 2025-01-03 10:10:49,724 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,725 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,726 - INFO - AFTER
# 2025-01-03 10:10:49,726 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,727 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,728 - INFO - OUTPUT
# 2025-01-03 10:10:49,728 - INFO -   output: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,728 - INFO - BEFORE
# 2025-01-03 10:10:49,730 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,730 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,731 - INFO - AFTER
# 2025-01-03 10:10:49,731 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,732 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,734 - INFO - OUTPUT
# 2025-01-03 10:10:49,735 - INFO -   output: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,737 - INFO - Debugging Linear forward.
# 2025-01-03 10:10:49,738 - INFO - BEFORE
# 2025-01-03 10:10:49,738 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,739 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,740 - INFO - AFTER
# 2025-01-03 10:10:49,741 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,742 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,743 - INFO - OUTPUT
# 2025-01-03 10:10:49,746 - INFO -   output: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,747 - INFO - BEFORE
# 2025-01-03 10:10:49,748 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,748 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,750 - INFO - AFTER
# 2025-01-03 10:10:49,751 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,752 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,754 - INFO - OUTPUT
# 2025-01-03 10:10:49,755 - INFO -   output: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,757 - INFO - Debugging Linear forward.
# 2025-01-03 10:10:49,758 - INFO - BEFORE
# 2025-01-03 10:10:49,759 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,760 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,762 - INFO - AFTER
# 2025-01-03 10:10:49,763 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,764 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,765 - INFO - OUTPUT
# 2025-01-03 10:10:49,766 - INFO -   output: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,767 - INFO - BEFORE
# 2025-01-03 10:10:49,768 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,768 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,770 - INFO - AFTER
# 2025-01-03 10:10:49,770 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,771 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,773 - INFO - OUTPUT
# 2025-01-03 10:10:49,773 - INFO -   output: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,775 - INFO - Debugging Linear forward.
# 2025-01-03 10:10:49,776 - INFO - BEFORE
# 2025-01-03 10:10:49,777 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,777 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,778 - INFO - AFTER
# 2025-01-03 10:10:49,779 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,780 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,781 - INFO - OUTPUT
# 2025-01-03 10:10:49,781 - INFO -   output: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,782 - INFO - BEFORE
# 2025-01-03 10:10:49,782 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,783 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,784 - INFO - AFTER
# 2025-01-03 10:10:49,785 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,786 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,787 - INFO - OUTPUT
# 2025-01-03 10:10:49,788 - INFO -   output: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,790 - INFO - Debugging Linear forward.
# 2025-01-03 10:10:49,791 - INFO - BEFORE
# 2025-01-03 10:10:49,792 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,792 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,794 - INFO - AFTER
# 2025-01-03 10:10:49,794 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,795 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,796 - INFO - OUTPUT
# 2025-01-03 10:10:49,797 - INFO -   output: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,798 - INFO - BEFORE
# 2025-01-03 10:10:49,798 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,799 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,801 - INFO - AFTER
# 2025-01-03 10:10:49,802 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,802 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,803 - INFO - OUTPUT
# 2025-01-03 10:10:49,809 - INFO -   output: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,812 - INFO - Debugging Linear forward.
# 2025-01-03 10:10:49,813 - INFO - BEFORE
# 2025-01-03 10:10:49,814 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,815 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,817 - INFO - AFTER
# 2025-01-03 10:10:49,817 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,818 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,819 - INFO - OUTPUT
# 2025-01-03 10:10:49,820 - INFO -   output: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,821 - INFO - BEFORE
# 2025-01-03 10:10:49,821 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,822 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,823 - INFO - AFTER
# 2025-01-03 10:10:49,824 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,825 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,826 - INFO - OUTPUT
# 2025-01-03 10:10:49,827 - INFO -   output: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,828 - INFO - Debugging Linear forward.
# 2025-01-03 10:10:49,828 - INFO - BEFORE
# 2025-01-03 10:10:49,829 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,829 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,831 - INFO - AFTER
# 2025-01-03 10:10:49,831 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,832 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,833 - INFO - OUTPUT
# 2025-01-03 10:10:49,833 - INFO -   output: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,834 - INFO - BEFORE
# 2025-01-03 10:10:49,834 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,835 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,837 - INFO - AFTER
# 2025-01-03 10:10:49,837 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,838 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,840 - INFO - OUTPUT
# 2025-01-03 10:10:49,841 - INFO -   output: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,843 - INFO - Debugging Linear forward.
# 2025-01-03 10:10:49,844 - INFO - BEFORE
# 2025-01-03 10:10:49,845 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,845 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,846 - INFO - AFTER
# 2025-01-03 10:10:49,847 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,847 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,848 - INFO - OUTPUT
# 2025-01-03 10:10:49,849 - INFO -   output: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,850 - INFO - BEFORE
# 2025-01-03 10:10:49,851 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,851 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,852 - INFO - AFTER
# 2025-01-03 10:10:49,853 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,854 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,855 - INFO - OUTPUT
# 2025-01-03 10:10:49,855 - INFO -   output: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,860 - INFO - Debugging Linear forward.
# 2025-01-03 10:10:49,861 - INFO - BEFORE
# 2025-01-03 10:10:49,862 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,863 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,864 - INFO - AFTER
# 2025-01-03 10:10:49,865 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,866 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,867 - INFO - OUTPUT
# 2025-01-03 10:10:49,871 - INFO -   output: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,873 - INFO - BEFORE
# 2025-01-03 10:10:49,874 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,875 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,876 - INFO - AFTER
# 2025-01-03 10:10:49,877 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,877 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,879 - INFO - OUTPUT
# 2025-01-03 10:10:49,880 - INFO -   output: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,881 - INFO - Debugging Linear forward.
# 2025-01-03 10:10:49,882 - INFO - BEFORE
# 2025-01-03 10:10:49,882 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,883 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,884 - INFO - AFTER
# 2025-01-03 10:10:49,885 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,886 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,888 - INFO - OUTPUT
# 2025-01-03 10:10:49,890 - INFO -   output: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,890 - INFO - BEFORE
# 2025-01-03 10:10:49,891 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,892 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,894 - INFO - AFTER
# 2025-01-03 10:10:49,895 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,895 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,897 - INFO - OUTPUT
# 2025-01-03 10:10:49,897 - INFO -   output: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,899 - INFO - Debugging Linear forward.
# 2025-01-03 10:10:49,901 - INFO - BEFORE
# 2025-01-03 10:10:49,902 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,903 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,905 - INFO - AFTER
# 2025-01-03 10:10:49,906 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,907 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,908 - INFO - OUTPUT
# 2025-01-03 10:10:49,909 - INFO -   output: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,909 - INFO - BEFORE
# 2025-01-03 10:10:49,910 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,911 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,912 - INFO - AFTER
# 2025-01-03 10:10:49,913 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,913 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,915 - INFO - OUTPUT
# 2025-01-03 10:10:49,915 - INFO -   output: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,918 - INFO - Debugging Linear forward.
# 2025-01-03 10:10:49,918 - INFO - BEFORE
# 2025-01-03 10:10:49,919 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,920 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,921 - INFO - AFTER
# 2025-01-03 10:10:49,922 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,923 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,925 - INFO - OUTPUT
# 2025-01-03 10:10:49,926 - INFO -   output: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,927 - INFO - BEFORE
# 2025-01-03 10:10:49,928 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,932 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,933 - INFO - AFTER
# 2025-01-03 10:10:49,934 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,934 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,936 - INFO - OUTPUT
# 2025-01-03 10:10:49,937 - INFO -   output: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,939 - INFO - Debugging Linear forward.
# 2025-01-03 10:10:49,943 - INFO - BEFORE
# 2025-01-03 10:10:49,944 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,945 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,948 - INFO - AFTER
# 2025-01-03 10:10:49,953 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,954 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,960 - INFO - OUTPUT
# 2025-01-03 10:10:49,962 - INFO -   output: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,962 - INFO - BEFORE
# 2025-01-03 10:10:49,963 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,965 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,965 - INFO - AFTER
# 2025-01-03 10:10:49,967 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,967 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,968 - INFO - OUTPUT
# 2025-01-03 10:10:49,968 - INFO -   output: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,970 - INFO - Debugging Linear forward.
# 2025-01-03 10:10:49,970 - INFO - BEFORE
# 2025-01-03 10:10:49,971 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,971 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,973 - INFO - AFTER
# 2025-01-03 10:10:49,973 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,974 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,976 - INFO - OUTPUT
# 2025-01-03 10:10:49,977 - INFO -   output: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,977 - INFO - BEFORE
# 2025-01-03 10:10:49,978 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,979 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,981 - INFO - AFTER
# 2025-01-03 10:10:49,981 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,982 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,988 - INFO - OUTPUT
# 2025-01-03 10:10:49,996 - INFO -   output: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:49,998 - INFO - Debugging Linear forward.
# 2025-01-03 10:10:50,004 - INFO - BEFORE
# 2025-01-03 10:10:50,005 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:50,013 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:50,016 - INFO - AFTER
# 2025-01-03 10:10:50,018 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:50,019 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:50,020 - INFO - OUTPUT
# 2025-01-03 10:10:50,020 - INFO -   output: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:50,022 - INFO - BEFORE
# 2025-01-03 10:10:50,023 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:50,024 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:50,025 - INFO - AFTER
# 2025-01-03 10:10:50,025 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:50,026 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:50,027 - INFO - OUTPUT
# 2025-01-03 10:10:50,029 - INFO -   output: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:50,031 - INFO - Debugging Linear forward.
# 2025-01-03 10:10:50,032 - INFO - BEFORE
# 2025-01-03 10:10:50,033 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:50,034 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:50,037 - INFO - AFTER
# 2025-01-03 10:10:50,038 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:50,039 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:50,040 - INFO - OUTPUT
# 2025-01-03 10:10:50,040 - INFO -   output: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:50,041 - INFO - BEFORE
# 2025-01-03 10:10:50,042 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:50,042 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:50,044 - INFO - AFTER
# 2025-01-03 10:10:50,045 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:50,046 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:50,047 - INFO - OUTPUT
# 2025-01-03 10:10:50,047 - INFO -   output: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:50,049 - INFO - Debugging Linear forward.
# 2025-01-03 10:10:50,050 - INFO - BEFORE
# 2025-01-03 10:10:50,051 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:50,052 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:50,053 - INFO - AFTER
# 2025-01-03 10:10:50,054 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:50,054 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:50,055 - INFO - OUTPUT
# 2025-01-03 10:10:50,056 - INFO -   output: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:50,056 - INFO - BEFORE
# 2025-01-03 10:10:50,056 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:50,057 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:50,059 - INFO - AFTER
# 2025-01-03 10:10:50,059 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:50,060 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:50,062 - INFO - OUTPUT
# 2025-01-03 10:10:50,062 - INFO -   output: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:50,064 - INFO - Debugging Linear forward.
# 2025-01-03 10:10:50,065 - INFO - BEFORE
# 2025-01-03 10:10:50,066 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:50,067 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:50,069 - INFO - AFTER
# 2025-01-03 10:10:50,070 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:50,071 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:50,072 - INFO - OUTPUT
# 2025-01-03 10:10:50,073 - INFO -   output: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:50,074 - INFO - BEFORE
# 2025-01-03 10:10:50,075 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:50,075 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:50,078 - INFO - AFTER
# 2025-01-03 10:10:50,078 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:50,079 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:50,081 - INFO - OUTPUT
# 2025-01-03 10:10:50,082 - INFO -   output: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:50,084 - INFO - Debugging Linear forward.
# 2025-01-03 10:10:50,085 - INFO - BEFORE
# 2025-01-03 10:10:50,086 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:50,087 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:50,088 - INFO - AFTER
# 2025-01-03 10:10:50,088 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:50,089 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:50,090 - INFO - OUTPUT
# 2025-01-03 10:10:50,091 - INFO -   output: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:50,092 - INFO - BEFORE
# 2025-01-03 10:10:50,092 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:50,093 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:50,094 - INFO - AFTER
# 2025-01-03 10:10:50,095 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:50,096 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:50,097 - INFO - OUTPUT
# 2025-01-03 10:10:50,098 - INFO -   output: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:50,100 - INFO - Debugging Linear forward.
# 2025-01-03 10:10:50,101 - INFO - BEFORE
# 2025-01-03 10:10:50,101 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:50,102 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:50,103 - INFO - AFTER
# 2025-01-03 10:10:50,104 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:50,105 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:50,106 - INFO - OUTPUT
# 2025-01-03 10:10:50,106 - INFO -   output: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:50,107 - INFO - BEFORE
# 2025-01-03 10:10:50,108 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:50,108 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:50,109 - INFO - AFTER
# 2025-01-03 10:10:50,110 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:50,110 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:50,111 - INFO - OUTPUT
# 2025-01-03 10:10:50,111 - INFO -   output: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:50,112 - INFO - Debugging Linear forward.
# 2025-01-03 10:10:50,113 - INFO - BEFORE
# 2025-01-03 10:10:50,114 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:50,114 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:50,115 - INFO - AFTER
# 2025-01-03 10:10:50,115 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:50,116 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:50,117 - INFO - OUTPUT
# 2025-01-03 10:10:50,117 - INFO -   output: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:50,118 - INFO - BEFORE
# 2025-01-03 10:10:50,118 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:50,119 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:50,120 - INFO - AFTER
# 2025-01-03 10:10:50,120 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:50,121 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:50,122 - INFO - OUTPUT
# 2025-01-03 10:10:50,122 - INFO -   output: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:50,123 - INFO - Debugging Linear forward.
# 2025-01-03 10:10:50,124 - INFO - BEFORE
# 2025-01-03 10:10:50,124 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:50,125 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:50,126 - INFO - AFTER
# 2025-01-03 10:10:50,126 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:50,127 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:50,128 - INFO - OUTPUT
# 2025-01-03 10:10:50,128 - INFO -   output: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:50,129 - INFO - BEFORE
# 2025-01-03 10:10:50,129 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:50,130 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:50,131 - INFO - AFTER
# 2025-01-03 10:10:50,131 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:50,132 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:50,133 - INFO - OUTPUT
# 2025-01-03 10:10:50,133 - INFO -   output: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:50,135 - INFO - Debugging Linear forward.
# 2025-01-03 10:10:50,136 - INFO - BEFORE
# 2025-01-03 10:10:50,137 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:50,137 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:50,138 - INFO - AFTER
# 2025-01-03 10:10:50,138 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:50,139 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:50,140 - INFO - OUTPUT
# 2025-01-03 10:10:50,141 - INFO -   output: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:50,141 - INFO - BEFORE
# ...
# 2025-01-03 10:10:51,164 - INFO - BEFORE
# 2025-01-03 10:10:51,165 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,166 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,167 - INFO - AFTER
# 2025-01-03 10:10:51,168 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,168 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,170 - INFO - OUTPUT
# 2025-01-03 10:10:51,171 - INFO -   output: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,173 - INFO - Debugging Linear forward.
# 2025-01-03 10:10:51,174 - INFO - BEFORE
# 2025-01-03 10:10:51,175 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,175 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,179 - INFO - AFTER
# 2025-01-03 10:10:51,181 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,182 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,186 - INFO - OUTPUT
# 2025-01-03 10:10:51,187 - INFO -   output: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,189 - INFO - BEFORE
# 2025-01-03 10:10:51,193 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,195 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,197 - INFO - AFTER
# 2025-01-03 10:10:51,198 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,200 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,201 - INFO - OUTPUT
# 2025-01-03 10:10:51,202 - INFO -   output: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,204 - INFO - Debugging Linear forward.
# 2025-01-03 10:10:51,205 - INFO - BEFORE
# 2025-01-03 10:10:51,206 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,207 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,208 - INFO - AFTER
# 2025-01-03 10:10:51,208 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,209 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,210 - INFO - OUTPUT
# 2025-01-03 10:10:51,211 - INFO -   output: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,211 - INFO - BEFORE
# 2025-01-03 10:10:51,212 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,212 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,213 - INFO - AFTER
# 2025-01-03 10:10:51,215 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,217 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,218 - INFO - OUTPUT
# 2025-01-03 10:10:51,219 - INFO -   output: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,222 - INFO - Debugging Linear forward.
# 2025-01-03 10:10:51,223 - INFO - BEFORE
# 2025-01-03 10:10:51,224 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,229 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,230 - INFO - AFTER
# 2025-01-03 10:10:51,235 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,236 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,239 - INFO - OUTPUT
# 2025-01-03 10:10:51,240 - INFO -   output: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,241 - INFO - BEFORE
# 2025-01-03 10:10:51,243 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,250 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,252 - INFO - AFTER
# 2025-01-03 10:10:51,253 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,253 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,255 - INFO - OUTPUT
# 2025-01-03 10:10:51,256 - INFO -   output: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,259 - INFO - Debugging Linear forward.
# 2025-01-03 10:10:51,259 - INFO - BEFORE
# 2025-01-03 10:10:51,260 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,262 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,263 - INFO - AFTER
# 2025-01-03 10:10:51,263 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,264 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,265 - INFO - OUTPUT
# 2025-01-03 10:10:51,266 - INFO -   output: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,267 - INFO - BEFORE
# 2025-01-03 10:10:51,268 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,269 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,270 - INFO - AFTER
# 2025-01-03 10:10:51,273 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,274 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,279 - INFO - OUTPUT
# 2025-01-03 10:10:51,281 - INFO -   output: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,283 - INFO - Debugging Linear forward.
# 2025-01-03 10:10:51,285 - INFO - BEFORE
# 2025-01-03 10:10:51,287 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,288 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,289 - INFO - AFTER
# 2025-01-03 10:10:51,290 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,291 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,292 - INFO - OUTPUT
# 2025-01-03 10:10:51,293 - INFO -   output: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,293 - INFO - BEFORE
# 2025-01-03 10:10:51,294 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,295 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,296 - INFO - AFTER
# 2025-01-03 10:10:51,296 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,296 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,297 - INFO - OUTPUT
# 2025-01-03 10:10:51,297 - INFO -   output: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,298 - INFO - Debugging Linear forward.
# 2025-01-03 10:10:51,299 - INFO - BEFORE
# 2025-01-03 10:10:51,299 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,300 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,300 - INFO - AFTER
# 2025-01-03 10:10:51,301 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,301 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,302 - INFO - OUTPUT
# 2025-01-03 10:10:51,303 - INFO -   output: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,303 - INFO - BEFORE
# 2025-01-03 10:10:51,304 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,304 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,305 - INFO - AFTER
# 2025-01-03 10:10:51,305 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,306 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,307 - INFO - OUTPUT
# 2025-01-03 10:10:51,307 - INFO -   output: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,309 - INFO - Debugging Linear forward.
# 2025-01-03 10:10:51,309 - INFO - BEFORE
# 2025-01-03 10:10:51,310 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,310 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,311 - INFO - AFTER
# 2025-01-03 10:10:51,312 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,312 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,313 - INFO - OUTPUT
# 2025-01-03 10:10:51,313 - INFO -   output: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,314 - INFO - BEFORE
# 2025-01-03 10:10:51,315 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,315 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,316 - INFO - AFTER
# 2025-01-03 10:10:51,316 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,317 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,318 - INFO - OUTPUT
# 2025-01-03 10:10:51,318 - INFO -   output: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,319 - INFO - Debugging Linear forward.
# 2025-01-03 10:10:51,320 - INFO - BEFORE
# 2025-01-03 10:10:51,320 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,321 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,322 - INFO - AFTER
# 2025-01-03 10:10:51,322 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,323 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,324 - INFO - OUTPUT
# 2025-01-03 10:10:51,324 - INFO -   output: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,325 - INFO - BEFORE
# 2025-01-03 10:10:51,325 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,326 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,327 - INFO - AFTER
# 2025-01-03 10:10:51,327 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,328 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,329 - INFO - OUTPUT
# 2025-01-03 10:10:51,329 - INFO -   output: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,345 - INFO - Debugging Linear forward.
# 2025-01-03 10:10:51,346 - INFO - BEFORE
# 2025-01-03 10:10:51,346 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,347 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,349 - INFO - AFTER
# 2025-01-03 10:10:51,353 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,354 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,355 - INFO - OUTPUT
# 2025-01-03 10:10:51,356 - INFO -   output: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,357 - INFO - BEFORE
# 2025-01-03 10:10:51,357 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,358 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,359 - INFO - AFTER
# 2025-01-03 10:10:51,360 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,361 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,362 - INFO - OUTPUT
# 2025-01-03 10:10:51,363 - INFO -   output: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,365 - INFO - Debugging Linear forward.
# 2025-01-03 10:10:51,366 - INFO - BEFORE
# 2025-01-03 10:10:51,367 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,367 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,369 - INFO - AFTER
# 2025-01-03 10:10:51,369 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,370 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,371 - INFO - OUTPUT
# 2025-01-03 10:10:51,372 - INFO -   output: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,372 - INFO - BEFORE
# 2025-01-03 10:10:51,373 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,375 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,376 - INFO - AFTER
# 2025-01-03 10:10:51,381 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,383 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,384 - INFO - OUTPUT
# 2025-01-03 10:10:51,386 - INFO -   output: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,389 - INFO - Debugging Linear forward.
# 2025-01-03 10:10:51,389 - INFO - BEFORE
# 2025-01-03 10:10:51,390 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,391 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,392 - INFO - AFTER
# 2025-01-03 10:10:51,393 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,393 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,395 - INFO - OUTPUT
# 2025-01-03 10:10:51,395 - INFO -   output: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,396 - INFO - BEFORE
# 2025-01-03 10:10:51,396 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,397 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,399 - INFO - AFTER
# 2025-01-03 10:10:51,399 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,400 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,401 - INFO - OUTPUT
# 2025-01-03 10:10:51,401 - INFO -   output: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,403 - INFO - Debugging Linear forward.
# 2025-01-03 10:10:51,404 - INFO - BEFORE
# 2025-01-03 10:10:51,405 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,405 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,406 - INFO - AFTER
# 2025-01-03 10:10:51,407 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,407 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,409 - INFO - OUTPUT
# 2025-01-03 10:10:51,409 - INFO -   output: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,410 - INFO - BEFORE
# 2025-01-03 10:10:51,411 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,412 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,413 - INFO - AFTER
# 2025-01-03 10:10:51,413 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,414 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,415 - INFO - OUTPUT
# 2025-01-03 10:10:51,416 - INFO -   output: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,417 - INFO - Debugging Linear forward.
# 2025-01-03 10:10:51,418 - INFO - BEFORE
# 2025-01-03 10:10:51,418 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,419 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,420 - INFO - AFTER
# 2025-01-03 10:10:51,421 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,421 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,423 - INFO - OUTPUT
# 2025-01-03 10:10:51,424 - INFO -   output: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,425 - INFO - BEFORE
# 2025-01-03 10:10:51,426 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,426 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,428 - INFO - AFTER
# 2025-01-03 10:10:51,428 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,429 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,431 - INFO - OUTPUT
# 2025-01-03 10:10:51,431 - INFO -   output: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,434 - INFO - Debugging Linear forward.
# 2025-01-03 10:10:51,434 - INFO - BEFORE
# 2025-01-03 10:10:51,435 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,436 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,437 - INFO - AFTER
# 2025-01-03 10:10:51,438 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,438 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,440 - INFO - OUTPUT
# 2025-01-03 10:10:51,441 - INFO -   output: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,442 - INFO - BEFORE
# 2025-01-03 10:10:51,442 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,444 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,445 - INFO - AFTER
# 2025-01-03 10:10:51,446 - INFO -   linear: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,446 - INFO -   input: device: cuda:0; dtype: torch.bfloat16
# 2025-01-03 10:10:51,448 - INFO - OUTPUT
# 2025-01-03 10:10:51,449 - INFO -   output: device: cuda:0; dtype: torch.bfloat16

# %%
logits_merged_e = get_logits(prompt, mergere.merger, tokenizer)
